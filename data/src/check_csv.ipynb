# %%
import os
import pandas as pd

# %%
album = 'Like Water For Chocolate'
artist = 'common'

# %%
script_dir = os.path.dirname(os.path.abspath('check_csv.ipynb'))
csv_file_path = os.path.join(script_dir, '..', 'albums', f'{album}', 'input', f'{artist}_like_water_for_chocolate_samples.csv')

# %%
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                         album album_artist  album_year  track_number  \
# 0    Like Water for Chocolate       Common        2000             1
# 1    Like Water for Chocolate       Common        2000             1
# 2    Like Water for Chocolate       Common        2000             1
# 3    Like Water for Chocolate       Common        2000             1
# 4    Like Water for Chocolate       Common        2000             1
# ..                        ...          ...         ...           ...
# 177  Like Water for Chocolate       Common        2000            12
# 178  Like Water for Chocolate       Common        2000            12
# 179  Like Water for Chocolate       Common        2000            13
# 180  Like Water for Chocolate       Common        2000            13
# 181  Like Water for Chocolate       Common        2000            13
#
#                   track_title track_artist     sample_type  \
# 0                   The Light       Common         sampled
# ...
